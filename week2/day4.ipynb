# %% [markdown]
# # Project - Airline AI Assistant
#
# We'll now bring together what we've learned to make an AI Customer Support assistant for an Airline

# %%
import os
import json
from dotenv import load_dotenv
from openai import OpenAI
import gradio as gr

# %%
import httpx
http_client=httpx.Client(verify=False)

# %%
# Initialization

load_dotenv(override=True)

openai_api_key = os.getenv('OPENAI_API_KEY')
if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
MODEL = "gpt-4.1-mini"
openai = OpenAI(http_client=http_client)

# As an alternative, if you'd like to use Ollama instead of OpenAI
# Check that Ollama is running for you locally (see week1/day2 exercise) then uncomment these next 2 lines
# MODEL = "llama3.2"
# openai = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')
# Out:
# OpenAI API Key exists and begins sk-proj-

# %%
system_message = """
You are a helpful assistant for an Airline called FlightAI.
Give short, courteous answers, no more than 1 sentence.
Always be accurate. If you don't know the answer, say so.
"""

# %%
def chat(message, history):
    history = [{"role":h["role"], "content":h["content"]} for h in history]
    messages = [{"role": "system", "content": system_message}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model=MODEL, messages=messages)
    return response.choices[0].message.content

gr.ChatInterface(fn=chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7887
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7887/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ## Tools
#
# Tools are an incredibly powerful feature provided by the frontier LLMs.
#
# With tools, you can write a function, and have the LLM call that function as part of its response.
#
# Sounds almost spooky.. we're giving it the power to run code on our machine?
#
# Well, kinda.

# %%
# Let's start by making a useful function

ticket_prices = {"london": "$799", "paris": "$899", "tokyo": "$1400", "berlin": "$499"}

def get_ticket_price(destination_city):
    print(f"Tool called for city {destination_city}")
    price = ticket_prices.get(destination_city.lower(), "Unknown ticket price")
    return f"The price of a ticket to {destination_city} is {price}"

# %%
get_ticket_price("London")
# Out:
# Tool called for city London
# 'The price of a ticket to London is $799'

# %%
# There's a particular dictionary structure that's required to describe our function:

price_function = {
    "name": "get_ticket_price",
    "description": "Get the price of a return ticket to the destination city.",
    "parameters": {
        "type": "object",
        "properties": {
            "destination_city": {
                "type": "string",
                "description": "The city that the customer wants to travel to",
            },
        },
        "required": ["destination_city"],
        "additionalProperties": False
    }
}

# %%
# And this is included in a list of tools:

tools = [{"type": "function", "function": price_function}]

# %%
tools
# Out:
# [{'type': 'function',
#   'function': {'name': 'get_ticket_price',
#    'description': 'Get the price of a return ticket to the destination city.',
#    'parameters': {'type': 'object',
#     'properties': {'destination_city': {'type': 'string',
#       'description': 'The city that the customer wants to travel to'}},
#     'required': ['destination_city'],
#     'additionalProperties': False}}}]

# %% [markdown]
# ## Getting OpenAI to use our Tool
#
# There's some fiddly stuff to allow OpenAI "to call our tool"
#
# What we actually do is give the LLM the opportunity to inform us that it wants us to run the tool.
#
# Here's how the new chat function looks:

# %%
def chat(message, history):
    history = [{"role":h["role"], "content":h["content"]} for h in history]
    messages = [{"role": "system", "content": system_message}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model=MODEL, messages=messages, tools=tools)

    if response.choices[0].finish_reason=="tool_calls":
        message = response.choices[0].message
        print(message)
        response = handle_tool_call(message)
        messages.append(message)
        messages.append(response)
        response = openai.chat.completions.create(model=MODEL, messages=messages)
    
    return response.choices[0].message.content

# %%
# We have to write that function handle_tool_call:

def handle_tool_call(message):
    tool_call = message.tool_calls[0]
    if tool_call.function.name == "get_ticket_price":
        arguments = json.loads(tool_call.function.arguments)
        city = arguments.get('destination_city')
        price_details = get_ticket_price(city)
        response = {
            "role": "tool",
            "content": price_details,
            "tool_call_id": tool_call.id
        }
    return response

# %%
gr.ChatInterface(fn=chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7893
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7893/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# ChatCompletionMessage(content=None, refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=[ChatCompletionMessageFunctionToolCall(id='call_uII2w5pd7uQzabM5179EOJ3u', function=Function(arguments='{"destination_city": "London"}', name='get_ticket_price'), type='function'), ChatCompletionMessageFunctionToolCall(id='call_cBKLMmMCoEPr93jO1bq9Fzf6', function=Function(arguments='{"destination_city": "Paris"}', name='get_ticket_price'), type='function')])
# Tool called for city London
# Traceback (most recent call last):
#   File "c:\Users\MT331AQ\projects\llm_engineering\.venv\Lib\site-packages\gradio\queueing.py", line 759, in process_events
#     response = await route_utils.call_process_api(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\MT331AQ\projects\llm_engineering\.venv\Lib\site-packages\gradio\route_utils.py", line 354, in call_process_api
#     output = await app.get_blocks().process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\MT331AQ\projects\llm_engineering\.venv\Lib\site-packages\gradio\blocks.py", line 2116, in process_api
#     result = await self.call_function(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\MT331AQ\projects\llm_engineering\.venv\Lib\site-packages\gradio\blocks.py", line 1621, in call_function
#     prediction = await fn(*processed_input)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\MT331AQ\projects\llm_engineering\.venv\Lib\site-packages\gradio\utils.py", line 882, in async_wrapper
#     response = await f(*args, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\MT331AQ\projects\llm_engineering\.venv\Lib\site-packages\gradio\chat_interface.py", line 553, in __wrapper
#     return await submit_fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\MT331AQ\projects\llm_engineering\.venv\Lib\site-packages\gradio\chat_interface.py", line 943, in _submit_fn
#     response = await anyio.to_thread.run_sync(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\MT331AQ\projects\llm_engineering\.venv\Lib\site-packages\anyio\to_thread.py", line 56, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\MT331AQ\projects\llm_engineering\.venv\Lib\site-packages\anyio\_backends\_asyncio.py", line 2485, in run_sync_in_worker_thread
#     return await future
#            ^^^^^^^^^^^^
#   File "c:\Users\MT331AQ\projects\llm_engineering\.venv\Lib\site-packages\anyio\_backends\_asyncio.py", line 976, in run
#     result = context.run(func, *args)
#              ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\MT331AQ\AppData\Local\Temp\ipykernel_2072\3496092768.py", line 12, in chat
#     response = openai.chat.completions.create(model=MODEL, messages=messages)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\MT331AQ\projects\llm_engineering\.venv\Lib\site-packages\openai\_utils\_utils.py", line 286, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\MT331AQ\projects\llm_engineering\.venv\Lib\site-packages\openai\resources\chat\completions\completions.py", line 1156, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "c:\Users\MT331AQ\projects\llm_engineering\.venv\Lib\site-packages\openai\_base_client.py", line 1259, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\MT331AQ\projects\llm_engineering\.venv\Lib\site-packages\openai\_base_client.py", line 1047, in request
#     raise self._make_status_error_from_response(err.response) from None
# openai.BadRequestError: Error code: 400 - {'error': {'message': "An assistant message with 'tool_calls' must be followed by tool messages responding to each 'tool_call_id'. The following tool_call_ids did not have response messages: call_cBKLMmMCoEPr93jO1bq9Fzf6", 'type': 'invalid_request_error', 'param': 'messages', 'code': None}}

# %% [markdown]
# ## Let's make a couple of improvements
#
# Handling multiple tool calls in 1 response
#
# Handling multiple tool calls 1 after another

# %%
def chat(message, history):
    history = [{"role":h["role"], "content":h["content"]} for h in history]
    messages = [{"role": "system", "content": system_message}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model=MODEL, messages=messages, tools=tools)

    if response.choices[0].finish_reason=="tool_calls":
        message = response.choices[0].message
        responses = handle_tool_calls(message)
        messages.append(message)
        messages.extend(responses)
        response = openai.chat.completions.create(model=MODEL, messages=messages)
    
    return response.choices[0].message.content

# %%
def handle_tool_calls(message):
    responses = []
    for tool_call in message.tool_calls:
        if tool_call.function.name == "get_ticket_price":
            arguments = json.loads(tool_call.function.arguments)
            city = arguments.get('destination_city')
            price_details = get_ticket_price(city)
            responses.append({
                "role": "tool",
                "content": price_details,
                "tool_call_id": tool_call.id
            })
    return responses

# %%
gr.ChatInterface(fn=chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7901
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7901/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# ChatCompletion(id='chatcmpl-CsNwqlXBmni0pcZVYspzveajW1HuV', choices=[Choice(finish_reason='tool_calls', index=0, logprobs=None, message=ChatCompletionMessage(content=None, refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=[ChatCompletionMessageFunctionToolCall(id='call_QhlM8XjsoR6l4YOQWPImqoiQ', function=Function(arguments='{"destination_city":"Tokyo"}', name='get_ticket_price'), type='function')]))], created=1767077804, model='gpt-4.1-mini-2025-04-14', object='chat.completion', service_tier='default', system_fingerprint='fp_376a7ccef1', usage=CompletionUsage(completion_tokens=16, prompt_tokens=129, total_tokens=145, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# Tool called for city Tokyo
# ChatCompletion(id='chatcmpl-CsNwsoGv5twmToEvkLyGOqDu65GUN', choices=[Choice(finish_reason='tool_calls', index=0, logprobs=None, message=ChatCompletionMessage(content=None, refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=[ChatCompletionMessageFunctionToolCall(id='call_OwHp2CmMmEfyJ8NG2lJ1kWwu', function=Function(arguments='{"destination_city":"Berlin"}', name='get_ticket_price'), type='function')]))], created=1767077806, model='gpt-4.1-mini-2025-04-14', object='chat.completion', service_tier='default', system_fingerprint='fp_376a7ccef1', usage=CompletionUsage(completion_tokens=16, prompt_tokens=165, total_tokens=181, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# Tool called for city Berlin
# ChatCompletion(id='chatcmpl-CsNwtMXajttmtpmc6VKupFLiRWPaZ', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='The ticket price to Tokyo is $1400, and the ticket price to Berlin is $499.', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1767077807, model='gpt-4.1-mini-2025-04-14', object='chat.completion', service_tier='default', system_fingerprint='fp_376a7ccef1', usage=CompletionUsage(completion_tokens=21, prompt_tokens=200, total_tokens=221, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# {'role': 'system', 'content': "\nYou are a helpful assistant for an Airline called FlightAI.\nGive short, courteous answers, no more than 1 sentence.\nAlways be accurate. If you don't know the answer, say so.\n"}
# {'role': 'user', 'content': 'get ticjet price for tokyo first and only if the price is more than 1000$ then only fetch the price for berlin'}
# ChatCompletionMessage(content=None, refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=[ChatCompletionMessageFunctionToolCall(id='call_QhlM8XjsoR6l4YOQWPImqoiQ', function=Function(arguments='{"destination_city":"Tokyo"}', name='get_ticket_price'), type='function')])
# {'role': 'tool', 'content': 'The price of a ticket to Tokyo is $1400', 'tool_call_id': 'call_QhlM8XjsoR6l4YOQWPImqoiQ'}
# ChatCompletionMessage(content=None, refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=[ChatCompletionMessageFunctionToolCall(id='call_OwHp2CmMmEfyJ8NG2lJ1kWwu', function=Function(arguments='{"destination_city":"Berlin"}', name='get_ticket_price'), type='function')])
# {'role': 'tool', 'content': 'The price of a ticket to Berlin is $499', 'tool_call_id': 'call_OwHp2CmMmEfyJ8NG2lJ1kWwu'}

# %%
def chat(message, history):
    history = [{"role":h["role"], "content":h["content"]} for h in history]
    messages = [{"role": "system", "content": system_message}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model=MODEL, messages=messages, tools=tools)
    print(response)

    while response.choices[0].finish_reason=="tool_calls":
        message = response.choices[0].message
        responses = handle_tool_calls(message)
        messages.append(message)
        messages.extend(responses)
        response = openai.chat.completions.create(model=MODEL, messages=messages, tools=tools)
        print(response)
    for ms in messages:
        print(ms)
    return response.choices[0].message.content

# %%
import sqlite3

# %%
DB = "prices.db"

with sqlite3.connect(DB) as conn:
    cursor = conn.cursor()
    cursor.execute('CREATE TABLE IF NOT EXISTS prices (city TEXT PRIMARY KEY, price REAL)')
    conn.commit()

# %%
def get_ticket_price(city):
    print(f"DATABASE TOOL CALLED: Getting price for {city}", flush=True)
    with sqlite3.connect(DB) as conn:
        cursor = conn.cursor()
        cursor.execute('SELECT price FROM prices WHERE city = ?', (city.lower(),))
        result = cursor.fetchone()
        return f"Ticket price to {city} is ${result[0]}" if result else "No price data available for this city"

# %%
get_ticket_price("London")
# Out:
# DATABASE TOOL CALLED: Getting price for London
# 'No price data available for this city'

# %%
def set_ticket_price(city, price):
    with sqlite3.connect(DB) as conn:
        cursor = conn.cursor()
        cursor.execute('INSERT INTO prices (city, price) VALUES (?, ?) ON CONFLICT(city) DO UPDATE SET price = ?', (city.lower(), price, price))
        conn.commit()

# %%
ticket_prices = {"london":799, "paris": 899, "tokyo": 1420, "sydney": 2999}
for city, price in ticket_prices.items():
    set_ticket_price(city, price)

# %%
get_ticket_price("Tokyo")
# Out:
# DATABASE TOOL CALLED: Getting price for Tokyo
# 'Ticket price to Tokyo is $1420.0'

# %%
gr.ChatInterface(fn=chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7902
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7902/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# ChatCompletion(id='chatcmpl-CsO0YTFNrngJFnZlekjyg9nhxvYiL', choices=[Choice(finish_reason='tool_calls', index=0, logprobs=None, message=ChatCompletionMessage(content=None, refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=[ChatCompletionMessageFunctionToolCall(id='call_WjF1FZNrQ8Slvq6re2MU6rbu', function=Function(arguments='{"destination_city":"Tokyo"}', name='get_ticket_price'), type='function')]))], created=1767078034, model='gpt-4.1-mini-2025-04-14', object='chat.completion', service_tier='default', system_fingerprint='fp_376a7ccef1', usage=CompletionUsage(completion_tokens=16, prompt_tokens=129, total_tokens=145, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# DATABASE TOOL CALLED: Getting price for Tokyo
# ChatCompletion(id='chatcmpl-CsO0aJytHHOmphfWvxGkquX9IRsNr', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='The ticket price to Tokyo is $1420, which is above $1000, so I will not fetch the price for Berlin.', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1767078036, model='gpt-4.1-mini-2025-04-14', object='chat.completion', service_tier='default', system_fingerprint='fp_376a7ccef1', usage=CompletionUsage(completion_tokens=28, prompt_tokens=164, total_tokens=192, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# {'role': 'system', 'content': "\nYou are a helpful assistant for an Airline called FlightAI.\nGive short, courteous answers, no more than 1 sentence.\nAlways be accurate. If you don't know the answer, say so.\n"}
# {'role': 'user', 'content': 'get ticjet price for tokyo first and only if the price is less than 1000$ then only fetch the price for berlin'}
# ChatCompletionMessage(content=None, refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=[ChatCompletionMessageFunctionToolCall(id='call_WjF1FZNrQ8Slvq6re2MU6rbu', function=Function(arguments='{"destination_city":"Tokyo"}', name='get_ticket_price'), type='function')])
# {'role': 'tool', 'content': 'Ticket price to Tokyo is $1420.0', 'tool_call_id': 'call_WjF1FZNrQ8Slvq6re2MU6rbu'}
# ChatCompletion(id='chatcmpl-CsO1LE0wRsk3sJPXYVTBcUegjatXW', choices=[Choice(finish_reason='tool_calls', index=0, logprobs=None, message=ChatCompletionMessage(content=None, refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=[ChatCompletionMessageFunctionToolCall(id='call_Hfk1ZTabS42QsMYKnzUEwcnH', function=Function(arguments='{"destination_city": "tokyo"}', name='get_ticket_price'), type='function'), ChatCompletionMessageFunctionToolCall(id='call_Ns1p8BeWrSfAUip5fnvATeHX', function=Function(arguments='{"destination_city": "berlin"}', name='get_ticket_price'), type='function')]))], created=1767078083, model='gpt-4.1-mini-2025-04-14', object='chat.completion', service_tier='default', system_fingerprint='fp_376a7ccef1', usage=CompletionUsage(completion_tokens=50, prompt_tokens=191, total_tokens=241, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# DATABASE TOOL CALLED: Getting price for tokyo
# DATABASE TOOL CALLED: Getting price for berlin
# ChatCompletion(id='chatcmpl-CsO1N4VsOmQ1jCtEePi4aSXgbzp0I', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='The ticket price to Tokyo is $1420, but I could not find the price for Berlin.', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1767078085, model='gpt-4.1-mini-2025-04-14', object='chat.completion', service_tier='default', system_fingerprint='fp_376a7ccef1', usage=CompletionUsage(completion_tokens=21, prompt_tokens=273, total_tokens=294, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# {'role': 'system', 'content': "\nYou are a helpful assistant for an Airline called FlightAI.\nGive short, courteous answers, no more than 1 sentence.\nAlways be accurate. If you don't know the answer, say so.\n"}
# {'role': 'user', 'content': 'get ticjet price for tokyo first and only if the price is less than 1000$ then only fetch the price for berlin'}
# {'role': 'assistant', 'content': 'The ticket price to Tokyo is $1420, which is above $1000, so I will not fetch the price for Berlin.'}
# {'role': 'user', 'content': 'get ticjet price for tokyo first and only if the price is more than 1000$ then only fetch the price for berlin'}
# ChatCompletionMessage(content=None, refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=[ChatCompletionMessageFunctionToolCall(id='call_Hfk1ZTabS42QsMYKnzUEwcnH', function=Function(arguments='{"destination_city": "tokyo"}', name='get_ticket_price'), type='function'), ChatCompletionMessageFunctionToolCall(id='call_Ns1p8BeWrSfAUip5fnvATeHX', function=Function(arguments='{"destination_city": "berlin"}', name='get_ticket_price'), type='function')])
# {'role': 'tool', 'content': 'Ticket price to tokyo is $1420.0', 'tool_call_id': 'call_Hfk1ZTabS42QsMYKnzUEwcnH'}
# {'role': 'tool', 'content': 'No price data available for this city', 'tool_call_id': 'call_Ns1p8BeWrSfAUip5fnvATeHX'}
# ChatCompletion(id='chatcmpl-CsO2IJHIZeoPgST2GxOkKEFXQlPvQ', choices=[Choice(finish_reason='tool_calls', index=0, logprobs=None, message=ChatCompletionMessage(content=None, refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=[ChatCompletionMessageFunctionToolCall(id='call_NIJ6zE6bvwORjoD8Z4xwu5l5', function=Function(arguments='{"destination_city":"tokyo"}', name='get_ticket_price'), type='function')]))], created=1767078142, model='gpt-4.1-mini-2025-04-14', object='chat.completion', service_tier='default', system_fingerprint='fp_376a7ccef1', usage=CompletionUsage(completion_tokens=17, prompt_tokens=246, total_tokens=263, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# DATABASE TOOL CALLED: Getting price for tokyo
# ChatCompletion(id='chatcmpl-CsO2IALl15OQWh6E969gzSmVBbLiM', choices=[Choice(finish_reason='tool_calls', index=0, logprobs=None, message=ChatCompletionMessage(content=None, refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=[ChatCompletionMessageFunctionToolCall(id='call_XTzsEifRBsE7ENgSQK2xMpJm', function=Function(arguments='{"destination_city":"london"}', name='get_ticket_price'), type='function')]))], created=1767078142, model='gpt-4.1-mini-2025-04-14', object='chat.completion', service_tier='default', system_fingerprint='fp_376a7ccef1', usage=CompletionUsage(completion_tokens=17, prompt_tokens=283, total_tokens=300, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# DATABASE TOOL CALLED: Getting price for london
# ChatCompletion(id='chatcmpl-CsO2KEsPCrVkDr8TwpsDvol7VLe9w', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='The ticket price to Tokyo is $1420, and the ticket price to London is $799.', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1767078144, model='gpt-4.1-mini-2025-04-14', object='chat.completion', service_tier='default', system_fingerprint='fp_376a7ccef1', usage=CompletionUsage(completion_tokens=21, prompt_tokens=318, total_tokens=339, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# {'role': 'system', 'content': "\nYou are a helpful assistant for an Airline called FlightAI.\nGive short, courteous answers, no more than 1 sentence.\nAlways be accurate. If you don't know the answer, say so.\n"}
# {'role': 'user', 'content': 'get ticjet price for tokyo first and only if the price is less than 1000$ then only fetch the price for berlin'}
# {'role': 'assistant', 'content': 'The ticket price to Tokyo is $1420, which is above $1000, so I will not fetch the price for Berlin.'}
# {'role': 'user', 'content': 'get ticjet price for tokyo first and only if the price is more than 1000$ then only fetch the price for berlin'}
# {'role': 'assistant', 'content': 'The ticket price to Tokyo is $1420, but I could not find the price for Berlin.'}
# {'role': 'user', 'content': 'get ticjet price for tokyo first and only if the price is more than 1000$ then only fetch the price for london'}
# ChatCompletionMessage(content=None, refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=[ChatCompletionMessageFunctionToolCall(id='call_NIJ6zE6bvwORjoD8Z4xwu5l5', function=Function(arguments='{"destination_city":"tokyo"}', name='get_ticket_price'), type='function')])
# {'role': 'tool', 'content': 'Ticket price to tokyo is $1420.0', 'tool_call_id': 'call_NIJ6zE6bvwORjoD8Z4xwu5l5'}
# ChatCompletionMessage(content=None, refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=[ChatCompletionMessageFunctionToolCall(id='call_XTzsEifRBsE7ENgSQK2xMpJm', function=Function(arguments='{"destination_city":"london"}', name='get_ticket_price'), type='function')])
# {'role': 'tool', 'content': 'Ticket price to london is $799.0', 'tool_call_id': 'call_XTzsEifRBsE7ENgSQK2xMpJm'}

# %% [markdown]
# ## Exercise
#
# Add a tool to set the price of a ticket!

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business Applications</h2>
#             <span style="color:#181;">Hopefully this hardly needs to be stated! You now have the ability to give actions to your LLMs. This Airline Assistant can now do more than answer questions - it could interact with booking APIs to make bookings!</span>
#         </td>
#     </tr>
# </table>
